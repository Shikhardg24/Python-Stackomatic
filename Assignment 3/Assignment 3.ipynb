# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.autograd as autograd
from torch.autograd import Variable
from collections import deque, namedtuple
import gymnasium as gym

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps. is_available() else
    "cpu"
)
device
# Out:
# device(type='cuda')

# %%
class ReplayMemory(object):

    def __init__(self, capacity):
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.capacity = capacity
        self.memory = []

    def push(self, event):
        self.memory.append(event)
        if len(self.memory) > self.capacity:
            del self.memory[0]
            
    def sample(self, batch_size):
        experiences = random.sample(self.memory, k = batch_size)
        states = torch.from_numpy(np.vstack([e[0] for e in experiences if e is not None])).float().to(self.device)
        actions = torch.from_numpy(np.vstack([e[1] for e in experiences if e is not None])).long().to(self.device)
        rewards = torch.from_numpy(np.vstack([e[2] for e in experiences if e is not None])).float().to(self.device)
        next_states = torch.from_numpy(np.vstack([e[3] for e in experiences if e is not None])).float().to(self.device)
        dones = torch.from_numpy(np.vstack([e[4] for e in experiences if e is not None]).astype(np.uint8)).float().to(self.device)
        return states, next_states, actions, rewards, dones

# %%
class Network(nn.Module):

    def __init__(self, state_size, action_size, seed = 42):
        super(Network, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)
    
    def forward(self, state):
        x = self.fc1(state)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        return self.fc3(x)

# %%
env = gym.make('LunarLander-v2')
state_shape = env.observation_space.shape
state_size = env.observation_space.shape[0]
number_actions = env.action_space.n
print('State shape: ', state_shape)
print('State size: ', state_size)
print('Number of actions: ', number_actions)
# Out:
# State shape:  (8,)
# State size:  8
# Number of actions:  4

# %%
learning_rate = 5e-4
minibatch_size = 200
discount_factor = 0.99
replay_buffer_size = int(1e5)
interpolation_parameter = 1e-3

n_actions = env.action_space.n
state_shape = env.observation_space.shape
state_size = env.observation_space.shape[0]


class Agent():

    def __init__(self, state_size, action_size):
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.state_size = state_size
        self.action_size = action_size
        self.local_qnetwork = Network(state_size, action_size).to(self.device)
        self.target_qnetwork = Network(state_size, action_size).to(self.device)
        self.optimizer = optim.Adam(self.local_qnetwork.parameters(), lr = learning_rate)
        self.memory = ReplayMemory(replay_buffer_size)
        self.t_step = 0


    def step(self, state, action, reward, next_state, done):
        self.memory.push((state, action, reward, next_state, done))
        self.t_step = (self.t_step + 1) % 4
        if self.t_step == 0:
            if len(self.memory.memory) > minibatch_size:
                experiences = self.memory.sample(200)
                self.learn(experiences, discount_factor)

        
    def act(self, state, epsilon = 0.):
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        self.local_qnetwork.eval()
        with torch.no_grad():
            action_values = self.local_qnetwork(state)
        self.local_qnetwork.train()
        if random.random() > epsilon:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
        
    def learn(self, experiences, discount_factor):
        states, next_states, actions, rewards, dones = experiences
        next_q_targets = self.target_qnetwork(next_states).detach().max(1)[0].unsqueeze(1)
        q_targets = rewards + discount_factor * next_q_targets * (1 - dones)
        q_expected = self.local_qnetwork(states).gather(1, actions)
        loss = F.mse_loss(q_expected, q_targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.soft_update(self.local_qnetwork, self.target_qnetwork, interpolation_parameter)
    
    def soft_update(self, local_model, target_model, interpolation_parameter):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(interpolation_parameter * local_param.data + (1.0 - interpolation_parameter) * target_param.data)

# %%
agent = Agent(state_size , n_actions)
number_episodes = 20000
maximum_number_timesteps_per_episode = 1000
epsilon_starting_value  = 1.0
epsilon_ending_value  = 0.0001
epsilon_decay_value  = 0.9995
epsilon = epsilon_starting_value
scores_on_100_episodes = deque(maxlen = 100)

for episode in range(1, number_episodes + 1):
  state, _ = env.reset()
  score = 0
  for t in range(maximum_number_timesteps_per_episode):
    action = agent.act(state, epsilon)
    next_state, reward, done, _, _ = env.step(action)
    agent.step(state, action, reward, next_state, done)
    state = next_state
    score += reward
    if done:
      break
  scores_on_100_episodes.append(score)
  epsilon = max(epsilon_ending_value, epsilon_decay_value * epsilon)
  print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode, np.mean(scores_on_100_episodes)), end = "")
  if episode % 100 == 0:
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode, np.mean(scores_on_100_episodes)))
  if np.mean(scores_on_100_episodes) >= 308:
    print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode - 100, np.mean(scores_on_100_episodes)))
    torch.save(agent.local_qnetwork.state_dict(), './checkpoint.pth')
    break
# Out:
# Episode 100	Average Score: -177.79
# Episode 200	Average Score: -157.33
# Episode 300	Average Score: -146.26
# Episode 400	Average Score: -122.63
# Episode 500	Average Score: -102.57
# Episode 600	Average Score: -103.35
# Episode 700	Average Score: -84.114
# Episode 800	Average Score: -84.92
# Episode 900	Average Score: -68.35
# Episode 1000	Average Score: -69.81
# Episode 1100	Average Score: -62.67
# Episode 1200	Average Score: -48.59
# Episode 1300	Average Score: -40.24
# Episode 1400	Average Score: -32.97
# Episode 1500	Average Score: -12.69
# Episode 1600	Average Score: 4.4961
# Episode 1700	Average Score: 11.83
# Episode 1800	Average Score: 15.29
# Episode 1900	Average Score: 20.40
# Episode 2000	Average Score: 58.58
# Episode 2100	Average Score: 48.18
# Episode 2200	Average Score: 47.32
# Episode 2300	Average Score: 44.18
# Episode 2400	Average Score: 61.58
# Episode 2500	Average Score: 75.51
# Episode 2600	Average Score: 83.50
# Episode 2700	Average Score: 95.50
# Episode 2800	Average Score: 106.37
# Episode 2900	Average Score: 122.95
# Episode 3000	Average Score: 157.16
# Episode 3100	Average Score: 151.23
# Episode 3200	Average Score: 151.28
# Episode 3300	Average Score: 177.80
# Episode 3400	Average Score: 192.81
# Episode 3500	Average Score: 198.71
# Episode 3600	Average Score: 210.20
# Episode 3700	Average Score: 201.71
# Episode 3800	Average Score: 209.68
# Episode 3900	Average Score: 205.53
# Episode 4000	Average Score: 209.18
# Episode 4100	Average Score: 196.61
# Episode 4200	Average Score: 234.61
# Episode 4300	Average Score: 156.89
# Episode 4400	Average Score: 215.09
# Episode 4500	Average Score: 243.58
# Episode 4600	Average Score: 242.68
# Episode 4700	Average Score: 245.13
# Episode 4800	Average Score: 253.46
# Episode 4900	Average Score: 251.75
# Episode 5000	Average Score: 248.72
# Episode 5100	Average Score: 225.01
# Episode 5200	Average Score: 196.17
# Episode 5300	Average Score: 181.39
# Episode 5400	Average Score: 150.35
# Episode 5500	Average Score: 191.95
# Episode 5600	Average Score: 239.38
# Episode 13900	Average Score: 266.02
# Episode 14000	Average Score: 264.30
# Episode 14100	Average Score: 266.12
# Episode 14200	Average Score: 271.79
# Episode 14300	Average Score: 271.87
# Episode 14400	Average Score: 277.69
# Episode 14500	Average Score: 280.24
# Episode 14600	Average Score: 277.74
# Episode 14700	Average Score: 253.70
# Episode 14800	Average Score: 265.28
# Episode 14900	Average Score: 276.67
# Episode 15000	Average Score: 274.29
# Episode 15100	Average Score: 279.63
# Episode 15200	Average Score: 279.18
# Episode 15300	Average Score: 269.53
# Episode 15400	Average Score: 273.39
# Episode 15500	Average Score: 260.89
# Episode 15600	Average Score: 217.73
# Episode 15700	Average Score: 262.99
# Episode 15800	Average Score: 265.99
# Episode 15900	Average Score: 268.80
# Episode 16000	Average Score: 247.14
# Episode 16100	Average Score: 259.62
# Episode 16200	Average Score: 274.24
# Episode 16300	Average Score: 268.82
# Episode 16400	Average Score: 274.23
# Episode 16500	Average Score: 272.62
# Episode 16600	Average Score: 272.89
# Episode 16700	Average Score: 276.62
# Episode 16800	Average Score: 269.61
# Episode 16900	Average Score: 268.02
# Episode 17000	Average Score: 274.58
# Episode 17100	Average Score: 265.21
# Episode 17200	Average Score: 279.37
# Episode 17300	Average Score: 275.86
# Episode 17400	Average Score: 278.82
# Episode 17500	Average Score: 279.68
# Episode 17600	Average Score: 280.72
# Episode 17700	Average Score: 280.03
# Episode 17800	Average Score: 271.91
# Episode 17900	Average Score: 274.02
# Episode 18000	Average Score: 269.87
# Episode 18100	Average Score: 262.56
# Episode 18200	Average Score: 269.34
# Episode 18300	Average Score: 279.31
# Episode 18400	Average Score: 258.47
# Episode 18500	Average Score: 272.32
# Episode 18600	Average Score: 273.52
# Episode 18700	Average Score: 280.91
# Episode 18800	Average Score: 277.42
# Episode 18900	Average Score: 277.65
# Episode 19000	Average Score: 276.94
# Episode 19100	Average Score: 271.51
# Episode 19200	Average Score: 274.30
# Episode 19300	Average Score: 258.36
# Episode 19400	Average Score: 256.57
# Episode 19500	Average Score: 266.44
# Episode 19600	Average Score: 248.47
# Episode 19700	Average Score: 233.27
# Episode 19800	Average Score: 244.08
# Episode 19900	Average Score: 259.12
# Episode 20000	Average Score: 263.55

# %%
import glob
import io
import base64
import imageio
from IPython.display import HTML, display
from gymnasium.wrappers.monitoring.video_recorder import VideoRecorder

def show_video_of_model(agent, env_name):
    env = gym.make(env_name, render_mode='rgb_array')
    state, _ = env.reset()
    done = False
    frames = []
    while not done:
        frame = env.render()
        frames.append(frame)
        action = agent.act(state)
        state, reward, done, _, _ = env.step(action.item())
    env.close()
    imageio.mimsave('video.mp4', frames, fps=30)

show_video_of_model(agent, 'LunarLander-v2')

def show_video():
    mp4list = glob.glob('*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

show_video()
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
torch.save(agent.local_qnetwork.state_dict(), './checkpoint.pth')
